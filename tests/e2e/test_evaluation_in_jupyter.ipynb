# %%
from datasets import load_dataset

# loading the V2 dataset
amnesty_qa = load_dataset("explodinggradients/amnesty_qa", "english_v2")
amnesty_qa
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# DatasetDict({
#     eval: Dataset({
#         features: ['question', 'ground_truth', 'answer', 'contexts'],
#         num_rows: 20
#     })
# })

# %%
from ragas.metrics import (
    answer_relevancy,
    faithfulness,
    context_recall,
    context_precision,
)

# %%
from ragas import evaluate

result = evaluate(
    amnesty_qa["eval"],
    metrics=[
        context_precision,
        faithfulness,
        answer_relevancy,
        context_recall,
    ],
)

result
# Out:
# Evaluating:   0%|          | 0/800 [00:00<?, ?it/s]
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# ---------------------------------------------------------------------------
# SSLWantReadError                          Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/anyio/streams/tls.py:131, in TLSStream._call_sslobject_method(self, func, *args)
#     130 try:
# --> 131     result = func(*args)
#     132 except ssl.SSLWantReadError:
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/ssl.py:917, in SSLObject.read(self, len, buffer)
#     916 else:
# --> 917     v = self._sslobj.read(len)
#     918 return v
#
# SSLWantReadError: The operation did not complete (read) (_ssl.c:2578)
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/lib/python3.10/asyncio/tasks.py:232, in Task.__step(***failed resolving arguments***)
#     229 if exc is None:
#     230     # We use the `send` method directly, because coroutines
#     231     # don't have `__iter__` and `__next__` methods.
# --> 232     result = coro.send(None)
#     233 else:
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:754, in BaseChatModel._agenerate_with_cache(self, messages, stop, run_manager, **kwargs)
#     753 if inspect.signature(self._agenerate).parameters.get("run_manager"):
# --> 754     result = await self._agenerate(
#     755         messages, stop=stop, run_manager=run_manager, **kwargs
#     756     )
#     757 else:
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/langchain_openai/chat_models/base.py:666, in BaseChatOpenAI._agenerate(self, messages, stop, run_manager, **kwargs)
#     665 params = {**params, **kwargs}
# --> 666 response = await self.async_client.create(messages=message_dicts, **params)
#     667 return self._create_chat_result(response)
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/openai/resources/chat/completions.py:1283, in AsyncCompletions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, service_tier, stop, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#    1249 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1250 async def create(
#    1251     self,
#    (...)
#    1281     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#    1282 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
# -> 1283     return await self._post(
#    1284         "/chat/completions",
#    1285         body=await async_maybe_transform(
#    1286             {
#    1287                 "messages": messages,
#    1288                 "model": model,
#    1289                 "frequency_penalty": frequency_penalty,
#    1290                 "function_call": function_call,
#    1291                 "functions": functions,
#    1292                 "logit_bias": logit_bias,
#    1293                 "logprobs": logprobs,
#    1294                 "max_tokens": max_tokens,
#    1295                 "n": n,
#    1296                 "parallel_tool_calls": parallel_tool_calls,
#    1297                 "presence_penalty": presence_penalty,
#    1298                 "response_format": response_format,
#    1299                 "seed": seed,
#    1300                 "service_tier": service_tier,
#    1301                 "stop": stop,
#    1302                 "stream": stream,
#    1303                 "stream_options": stream_options,
#    1304                 "temperature": temperature,
#    1305                 "tool_choice": tool_choice,
#    1306                 "tools": tools,
#    1307                 "top_logprobs": top_logprobs,
#    1308                 "top_p": top_p,
#    1309                 "user": user,
#    1310             },
#    1311             completion_create_params.CompletionCreateParams,
#    1312         ),
#    1313         options=make_request_options(
#    1314             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1315         ),
#    1316         cast_to=ChatCompletion,
#    1317         stream=stream or False,
#    1318         stream_cls=AsyncStream[ChatCompletionChunk],
#    1319     )
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/openai/_base_client.py:1805, in AsyncAPIClient.post(self, path, cast_to, body, files, options, stream, stream_cls)
#    1802 opts = FinalRequestOptions.construct(
#    1803     method="post", url=path, json_data=body, files=await async_to_httpx_files(files), **options
#    1804 )
# -> 1805 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/openai/_base_client.py:1503, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1494 async def request(
#    1495     self,
#    1496     cast_to: Type[ResponseT],
#    (...)
#    1501     remaining_retries: Optional[int] = None,
#    1502 ) -> ResponseT | _AsyncStreamT:
# -> 1503     return await self._request(
#    1504         cast_to=cast_to,
#    1505         options=options,
#    1506         stream=stream,
#    1507         stream_cls=stream_cls,
#    1508         remaining_retries=remaining_retries,
#    1509     )
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/openai/_base_client.py:1537, in AsyncAPIClient._request(self, cast_to, options, stream, stream_cls, remaining_retries)
#    1536 try:
# -> 1537     response = await self._client.send(
#    1538         request,
#    1539         stream=stream or self._should_stream_response_body(request=request),
#    1540         **kwargs,
#    1541     )
#    1542 except httpx.TimeoutException as err:
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/httpx/_client.py:1617, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1615 auth = self._build_request_auth(request, auth)
# -> 1617 response = await self._send_handling_auth(
#    1618     request,
#    1619     auth=auth,
#    1620     follow_redirects=follow_redirects,
#    1621     history=[],
#    1622 )
#    1623 try:
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/httpx/_client.py:1645, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1644 while True:
# -> 1645     response = await self._send_handling_redirects(
#    1646         request,
#    1647         follow_redirects=follow_redirects,
#    1648         history=history,
#    1649     )
#    1650     try:
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/httpx/_client.py:1682, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1680     await hook(request)
# -> 1682 response = await self._send_single_request(request)
#    1683 try:
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/httpx/_client.py:1719, in AsyncClient._send_single_request(self, request)
#    1718 with request_context(request=request):
# -> 1719     response = await transport.handle_async_request(request)
#    1721 assert isinstance(response.stream, AsyncByteStream)
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/httpx/_transports/default.py:366, in AsyncHTTPTransport.handle_async_request(self, request)
#     365 with map_httpcore_exceptions():
# --> 366     resp = await self._pool.handle_async_request(req)
#     368 assert isinstance(resp.stream, typing.AsyncIterable)
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/httpcore/_async/connection_pool.py:268, in AsyncConnectionPool.handle_async_request(self, request)
#     267         await self.response_closed(status)
# --> 268     raise exc
#     269 else:
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/httpcore/_async/connection_pool.py:251, in AsyncConnectionPool.handle_async_request(self, request)
#     250 try:
# --> 251     response = await connection.handle_async_request(request)
#     252 except ConnectionNotAvailable:
#     253     # The ConnectionNotAvailable exception is a special case, that
#     254     # indicates we need to retry the request on a new connection.
#    (...)
#     258     # might end up as an HTTP/2 connection, but which actually ends
#     259     # up as HTTP/1.1.
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/httpcore/_async/connection.py:103, in AsyncHTTPConnection.handle_async_request(self, request)
#     101         raise ConnectionNotAvailable()
# --> 103 return await self._connection.handle_async_request(request)
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/httpcore/_async/http11.py:133, in AsyncHTTP11Connection.handle_async_request(self, request)
#     132         await self._response_closed()
# --> 133 raise exc
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/httpcore/_async/http11.py:111, in AsyncHTTP11Connection.handle_async_request(self, request)
#     103 async with Trace(
#     104     "receive_response_headers", logger, request, kwargs
#     105 ) as trace:
#     106     (
#     107         http_version,
#     108         status,
#     109         reason_phrase,
#     110         headers,
# --> 111     ) = await self._receive_response_headers(**kwargs)
#     112     trace.return_value = (
#     113         http_version,
#     114         status,
#     115         reason_phrase,
#     116         headers,
#     117     )
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/httpcore/_async/http11.py:176, in AsyncHTTP11Connection._receive_response_headers(self, request)
#     175 while True:
# --> 176     event = await self._receive_event(timeout=timeout)
#     177     if isinstance(event, h11.Response):
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/httpcore/_async/http11.py:212, in AsyncHTTP11Connection._receive_event(self, timeout)
#     211 if event is h11.NEED_DATA:
# --> 212     data = await self._network_stream.read(
#     213         self.READ_NUM_BYTES, timeout=timeout
#     214     )
#     216     # If we feed this case through h11 we'll raise an exception like:
#     217     #
#     218     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     222     # perspective. Instead we handle this case distinctly and treat
#     223     # it as a ConnectError.
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/httpcore/_backends/anyio.py:34, in AnyIOStream.read(self, max_bytes, timeout)
#      33 try:
# ---> 34     return await self._stream.receive(max_bytes=max_bytes)
#      35 except anyio.EndOfStream:  # pragma: nocover
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/anyio/streams/tls.py:196, in TLSStream.receive(self, max_bytes)
#     195 async def receive(self, max_bytes: int = 65536) -> bytes:
# --> 196     data = await self._call_sslobject_method(self._ssl_object.read, max_bytes)
#     197     if not data:
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/anyio/streams/tls.py:138, in TLSStream._call_sslobject_method(self, func, *args)
#     136         await self.transport_stream.send(self._write_bio.read())
# --> 138     data = await self.transport_stream.receive()
#     139 except EndOfStream:
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/anyio/_backends/_asyncio.py:1203, in SocketStream.receive(self, max_bytes)
#    1202 self._transport.resume_reading()
# -> 1203 await self._protocol.read_event.wait()
#    1204 self._transport.pause_reading()
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/asyncio/locks.py:214, in Event.wait(self)
#     213 try:
# --> 214     await fut
#     215     return True
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/asyncio/futures.py:285, in Future.__await__(self)
#     284     self._asyncio_future_blocking = True
# --> 285     yield self  # This tells Task to wait for completion.
#     286 if not self.done():
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/asyncio/tasks.py:304, in Task.__wakeup(self, future)
#     303 try:
# --> 304     future.result()
#     305 except BaseException as exc:
#     306     # This may also be a cancellation.
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/asyncio/futures.py:196, in Future.result(self)
#     195     exc = self._make_cancelled_error()
# --> 196     raise exc
#     197 if self._state != _FINISHED:
#
# CancelledError:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/lib/python3.10/asyncio/tasks.py:234, in Task.__step(***failed resolving arguments***)
#     233     else:
# --> 234         result = coro.throw(exc)
#     235 except StopIteration as exc:
#
# File ~/jjmachan/explodinggradients/ragas/src/ragas/metrics/_faithfulness.py:266, in Faithfulness._ascore(self, row, callbacks, is_async)
#     265 p_value = self._create_nli_prompt(row, statements)
# --> 266 nli_result = await self.llm.generate(
#     267     p_value,
#     268     callbacks=callbacks,
#     269     is_async=is_async,
#     270     n=self._reproducibility,
#     271 )
#     273 nli_result_text = [
#     274     nli_result.generations[0][i].text for i in range(self._reproducibility)
#     275 ]
#
# File ~/jjmachan/explodinggradients/ragas/src/ragas/llms/base.py:93, in BaseRagasLLM.generate(self, prompt, n, temperature, stop, callbacks, is_async)
#      90     agenerate_text_with_retry = add_async_retry(
#      91         self.agenerate_text, self.run_config
#      92     )
# ---> 93     return await agenerate_text_with_retry(
#      94         prompt=prompt,
#      95         n=n,
#      96         temperature=temperature,
#      97         stop=stop,
#      98         callbacks=callbacks,
#      99     )
#     100 else:
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/tenacity/_asyncio.py:88, in AsyncRetrying.wraps.<locals>.async_wrapped(*args, **kwargs)
#      86 @functools.wraps(fn)
#      87 async def async_wrapped(*args: t.Any, **kwargs: t.Any) -> t.Any:
# ---> 88     return await fn(*args, **kwargs)
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/tenacity/_asyncio.py:47, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#      46 while True:
# ---> 47     do = self.iter(retry_state=retry_state)
#      48     if isinstance(do, DoAttempt):
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/tenacity/__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     402 try:
# --> 403     raise self._exception
#     404 finally:
#     405     # Break a reference cycle with the exception in self._exception
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/tenacity/_asyncio.py:50, in AsyncRetrying.__call__(self, fn, *args, **kwargs)
#      49 try:
# ---> 50     result = await fn(*args, **kwargs)
#      51 except BaseException:  # noqa: B902
#
# File ~/jjmachan/explodinggradients/ragas/src/ragas/llms/base.py:170, in LangchainLLMWrapper.agenerate_text(self, prompt, n, temperature, stop, callbacks)
#     169 if is_multiple_completion_supported(self.langchain_llm):
# --> 170     return await self.langchain_llm.agenerate_prompt(
#     171         prompts=[prompt],
#     172         n=n,
#     173         temperature=temperature,
#     174         stop=stop,
#     175         callbacks=callbacks,
#     176     )
#     177 else:
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:609, in BaseChatModel.agenerate_prompt(self, prompts, stop, callbacks, **kwargs)
#     608 prompt_messages = [p.to_messages() for p in prompts]
# --> 609 return await self.agenerate(
#     610     prompt_messages, stop=stop, callbacks=callbacks, **kwargs
#     611 )
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/langchain_core/language_models/chat_models.py:535, in BaseChatModel.agenerate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     525 run_managers = await callback_manager.on_chat_model_start(
#     526     dumpd(self),
#     527     messages,
#    (...)
#     532     run_id=run_id,
#     533 )
# --> 535 results = await asyncio.gather(
#     536     *[
#     537         self._agenerate_with_cache(
#     538             m,
#     539             stop=stop,
#     540             run_manager=run_managers[i] if run_managers else None,
#     541             **kwargs,
#     542         )
#     543         for i, m in enumerate(messages)
#     544     ],
#     545     return_exceptions=True,
#     546 )
#     547 exceptions = []
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/asyncio/tasks.py:304, in Task.__wakeup(self, future)
#     303 try:
# --> 304     future.result()
#     305 except BaseException as exc:
#     306     # This may also be a cancellation.
#
# CancelledError:
#
# During handling of the above exception, another exception occurred:
#
# CancelledError                            Traceback (most recent call last)
# File ~/.pyenv/versions/3.10.12/lib/python3.10/asyncio/tasks.py:456, in wait_for(fut, timeout)
#     455 try:
# --> 456     return fut.result()
#     457 except exceptions.CancelledError as exc:
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/asyncio/futures.py:196, in Future.result(self)
#     195     exc = self._make_cancelled_error()
# --> 196     raise exc
#     197 if self._state != _FINISHED:
#
# CancelledError:
#
# The above exception was the direct cause of the following exception:
#
# TimeoutError                              Traceback (most recent call last)
# Cell In[6], line 3
#       1 from ragas import evaluate
# ----> 3 result = evaluate(
#       4     bigger_ds,
#       5     metrics=[
#       6         context_precision,
#       7         faithfulness,
#       8         answer_relevancy,
#       9         context_recall,
#      10     ],
#      11 )
#      13 result
#
# File ~/jjmachan/explodinggradients/ragas/src/ragas/evaluation.py:255, in evaluate(dataset, metrics, llm, embeddings, callbacks, in_ci, is_async, run_config, raise_exceptions, column_map)
#     252     if not evaluation_group_cm.ended:
#     253         evaluation_rm.on_chain_error(e)
# --> 255     raise e
#     256 else:
#     257     result = Result(
#     258         scores=Dataset.from_list(scores),
#     259         dataset=dataset,
#     260         binary_columns=binary_metrics,
#     261     )
#
# File ~/jjmachan/explodinggradients/ragas/src/ragas/evaluation.py:235, in evaluate(dataset, metrics, llm, embeddings, callbacks, in_ci, is_async, run_config, raise_exceptions, column_map)
#     232 scores = []
#     233 try:
#     234     # get the results
# --> 235     results = executor.results()
#     236     if results == []:
#     237         raise ExceptionInRunner()
#
# File ~/jjmachan/explodinggradients/ragas/src/ragas/executor.py:107, in Executor.results(self)
#     103         results.append(r)
#     105     return results
# --> 107 results = asyncio.run(_aresults())
#     108 sorted_results = sorted(results, key=lambda x: x[0])
#     109 return [r[1] for r in sorted_results]
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/nest_asyncio.py:31, in _patch_asyncio.<locals>.run(main, debug)
#      29 task = asyncio.ensure_future(main)
#      30 try:
# ---> 31     return loop.run_until_complete(task)
#      32 finally:
#      33     if not task.done():
#
# File ~/.pyenv/versions/3.10.12/envs/ragas/lib/python3.10/site-packages/nest_asyncio.py:99, in _patch_loop.<locals>.run_until_complete(self, future)
#      96 if not f.done():
#      97     raise RuntimeError(
#      98         'Event loop stopped before Future completed.')
# ---> 99 return f.result()
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception.with_traceback(self._exception_tb)
#     202 return self._result
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/asyncio/tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# File ~/jjmachan/explodinggradients/ragas/src/ragas/executor.py:102, in Executor.results.<locals>._aresults()
#      94 results = []
#      95 for future in tqdm(
#      96     futures_as_they_finish,
#      97     desc=self.desc,
#    (...)
#     100     leave=self.keep_progress_bar,
#     101 ):
# --> 102     r = await future
#     103     results.append(r)
#     105 return results
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/asyncio/tasks.py:571, in as_completed.<locals>._wait_for_one()
#     568 if f is None:
#     569     # Dummy value from _on_timeout().
#     570     raise exceptions.TimeoutError
# --> 571 return f.result()
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/asyncio/futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception.with_traceback(self._exception_tb)
#     202 return self._result
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/asyncio/tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# File ~/jjmachan/explodinggradients/ragas/src/ragas/executor.py:34, in as_completed.<locals>.sema_coro(coro)
#      32 async def sema_coro(coro):
#      33     async with semaphore:
# ---> 34         return await coro
#
# File ~/jjmachan/explodinggradients/ragas/src/ragas/executor.py:59, in Executor.wrap_callable_with_index.<locals>.wrapped_callable_async(*args, **kwargs)
#      57 except Exception as e:
#      58     if self.raise_exceptions:
# ---> 59         raise e
#      60     else:
#      61         logger.error(
#      62             "Runner in Executor raised an exception", exc_info=False
#      63         )
#
# File ~/jjmachan/explodinggradients/ragas/src/ragas/executor.py:53, in Executor.wrap_callable_with_index.<locals>.wrapped_callable_async(*args, **kwargs)
#      51 result = np.nan
#      52 try:
# ---> 53     result = await callable(*args, **kwargs)
#      54 except MaxRetriesExceeded as e:
#      55     # this only for testset generation v2
#      56     logger.warning(f"max retries exceeded for {e.evolution}")
#
# File ~/jjmachan/explodinggradients/ragas/src/ragas/metrics/base.py:134, in Metric.ascore(self, row, callbacks, is_async, thread_timeout)
#     132     if not group_cm.ended:
#     133         rm.on_chain_error(e)
# --> 134     raise e
#     135 else:
#     136     if not group_cm.ended:
#
# File ~/jjmachan/explodinggradients/ragas/src/ragas/metrics/base.py:127, in Metric.ascore(self, row, callbacks, is_async, thread_timeout)
#     123 rm, group_cm = new_group(
#     124     self.name, inputs=row, callbacks=callbacks, is_async=True
#     125 )
#     126 try:
# --> 127     score = await asyncio.wait_for(
#     128         self._ascore(row=row, callbacks=group_cm, is_async=is_async),
#     129         timeout=thread_timeout,
#     130     )
#     131 except Exception as e:
#     132     if not group_cm.ended:
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/asyncio/tasks.py:458, in wait_for(fut, timeout)
#     456             return fut.result()
#     457         except exceptions.CancelledError as exc:
# --> 458             raise exceptions.TimeoutError() from exc
#     459 finally:
#     460     timeout_handle.cancel()
#
# TimeoutError:
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
# Failed to batch ingest runs: LangSmithRateLimitError('Rate limit exceeded for https://api.smith.langchain.com/runs/batch. HTTPError(\'429 Client Error: Too Many Requests for url: https://api.smith.langchain.com/runs/batch\', \'{"detail":"Monthly unique traces usage limit exceeded"}\')')
